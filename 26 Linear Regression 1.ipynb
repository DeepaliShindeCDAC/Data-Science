# %%
import numpy as np

# %%
# x is values of height in cms
x= np.array([[151],[174],[138],[186],[128],[136],[179],[163],[152],[131]])

# y is values of weight inkgs
y= np.array([63,81,56,91,47,57,76,72,62,48])

# %%
from sklearn.linear_model import LinearRegression

# %%
  #create the object
regressor  =LinearRegression()

# %%
#train the algorithm
regressor.fit(x,y)
# Out:
# LinearRegression()

# %%
# m
regressor.coef_
# Out:
# array([0.67461045])

# %%
# c
regressor.intercept_
# Out:
# -38.45508707607698

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)

# %%
regressor.predict([[185]])
# Out:
# array([86.34784601])

# %%
# m*x+c

# %%
0.67461045*185 -38.45508707607698
# Out:
# 86.34784617392302

# %%
regressor.predict([[128]])
# Out:
# array([47.89505041])
