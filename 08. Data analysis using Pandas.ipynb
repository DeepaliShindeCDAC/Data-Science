# %%
import pandas as pd

# %% [markdown]
# ##### Series

# %%
s=pd.Series([56,34,89,12,46,78])

# %%
s
# Out:
# 0    56
# 1    34
# 2    89
# 3    12
# 4    46
# 5    78
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.ndim,s.shape, s.size
# Out:
# (1, (6,), 6)

# %% [markdown]
# #### Data Frame

# %%
r= pd.Series([1,2,3,4,5])
n=pd.Series(["Ram","Geeta","Ram","Raj","Deepali"])
m= pd.Series([66,34.45,56,9.44,95.34])

# %%
df = pd.DataFrame({
    'roll':r,
    'name':n,
    'marks':m
})

# %%
df
# Out:
#    roll     name  marks
# 0     1      Ram  66.00
# 1     2    Geeta  34.45
# 2     3      Ram  56.00
# 3     4      Raj   9.44
# 4     5  Deepali  95.34

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# marks    float64
# dtype: object

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'marks'], dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of    roll     name  marks
# 0     1      Ram  66.00
# 1     2    Geeta  34.45
# 2     3      Ram  56.00
# 3     4      Raj   9.44
# 4     5  Deepali  95.34>

# %%
#### working with datasets

# %%
# location https://mitu.co.in/dataset
# download all the files, name start with student
# and store in current workin directory

# %%
import os
os.getcwd() #get current working directoryp
# Out:
# 'C:\\Users\\Dipali Shinde\\Desktop\\Data_science_course'

# %%
df = pd.read_csv("datasets/student.csv")

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df["name"]
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df1 = pd.read_csv("datasets/student1.csv")

# %%
df1
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
df1 = pd.read_csv("datasets/student1.csv", names=['A','B','C','D','E'])

# %%
df1
# Out:
#     A        B   C      D   E
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
df3 = pd.read_csv("datasets/student3.tsv")
df3
# Out:
#   roll\tname\tclass\tmarks\tage
# 0        1\tanil\tTE\t56.77\t22
# 1        2\tamit\tTE\t59.77\t21
# 2      3\taniket\tBE\t76.88\t19
# 3     4\tajinkya\tTE\t69.66\t20
# 4        5\tasha\tTE\t63.28\t20
# 5      6\tayesha\tBE\t49.55\t20
# 6        7\tamar\tBE\t65.34\t19
# 7       8\tamita\tBE\t68.33\t23
# 8        9\tamol\tTE\t56.75\t20
# 9      10\tanmol\tBE\t78.66\t21

# %%
df3 = pd.read_csv("datasets/student3.tsv",sep='\t')
df3
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df3.columns[1]
# Out:
# 'name'

# %%
df3.columns =['roll', 'full name', 'class', 'marks', 'age']

# %% [markdown]
# ###

# %%
df3
# Out:
#    roll full name class  marks  age
# 0     1      anil    TE  56.77   22
# 1     2      amit    TE  59.77   21
# 2     3    aniket    BE  76.88   19
# 3     4   ajinkya    TE  69.66   20
# 4     5      asha    TE  63.28   20
# 5     6    ayesha    BE  49.55   20
# 6     7      amar    BE  65.34   19
# 7     8     amita    BE  68.33   23
# 8     9      amol    TE  56.75   20
# 9    10     anmol    BE  78.66   21

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.tail(2)
# Out:
#    roll   name class  marks  age
# 8     9   amol    TE  56.75   20
# 9    10  anmol    BE  78.66   21

# %% [markdown]
# #### slicing

# %%
df.iloc[2:8,1:4] # retriving by coloumn index
# Out:
#       name class  marks
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66
# 4     asha    TE  63.28
# 5   ayesha    BE  49.55
# 6     amar    BE  65.34
# 7    amita    BE  68.33

# %%
df.iloc[4,1:4]
# Out:
# name      asha
# class       TE
# marks    63.28
# Name: 4, dtype: object

# %%
df.iloc[[6,9,4,2],:4]
# Out:
#    roll    name class  marks
# 6     7    amar    BE  65.34
# 9    10   anmol    BE  78.66
# 4     5    asha    TE  63.28
# 2     3  aniket    BE  76.88

# %%
df.iloc[[6,9,4,2],[1,3]]
# Out:
#      name  marks
# 6    amar  65.34
# 9   anmol  78.66
# 4    asha  63.28
# 2  aniket  76.88

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[[6,9,4,2],:-1]
# Out:
#    roll    name class  marks
# 6     7    amar    BE  65.34
# 9    10   anmol    BE  78.66
# 4     5    asha    TE  63.28
# 2     3  aniket    BE  76.88

# %%
df.loc[:,'name'] # retriving by coloumn name
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:,['name','age']]
# Out:
#       name  age
# 0     anil   22
# 1     amit   21
# 2   aniket   19
# 3  ajinkya   20
# 4     asha   20
# 5   ayesha   20
# 6     amar   19
# 7    amita   23
# 8     amol   20
# 9    anmol   21

# %%
df[['name','age']]
# Out:
#       name  age
# 0     anil   22
# 1     amit   21
# 2   aniket   19
# 3  ajinkya   20
# 4     asha   20
# 5   ayesha   20
# 6     amar   19
# 7    amita   23
# 8     amol   20
# 9    anmol   21

# %%
df["name"]
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.name # if u want all rows and only one coloumn
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
list(range(1,11,2))
# Out:
# [1, 3, 5, 7, 9]

# %%
df.iloc[range(1,11,2)] # extracting only odd rows
# Out:
#    roll     name class  marks  age
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 5     6   ayesha    BE  49.55   20
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
import numpy as np

# %%
np.random.randint(1,10)  # random no
# Out:
# 2

# %%
num = [np.random.randint(1,10) for x in range(5)]
num
# Out:
# [9, 8, 8, 6, 3]

# %%
df.iloc[num]
# Out:
#    roll     name class  marks  age
# 9    10    anmol    BE  78.66   21
# 8     9     amol    TE  56.75   20
# 8     9     amol    TE  56.75   20
# 6     7     amar    BE  65.34   19
# 3     4  ajinkya    TE  69.66   20

# %%
df.drop(5) # drop at 5 index record
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[1,1]
# Out:
# 'amit'

# %%
df.iloc[1,1] ="deepali"

# %%
df.iloc[1,1]
# Out:
# 'deepali'

# %%
df.iloc[1,1] =np.nan # null value

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2      NaN    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[1,1] ="amit"

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df3 = pd.read_csv("datasets/student3.csv")

# %%
df3
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df3['age']
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4      NaN
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10     NaN
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df3['age'].fillna(20)  # fill 20 in NaN
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10    20.0
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df3['age'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: age, dtype: bool

# %%
df3.loc[df3['age'].isnull()]
# Out:
#     roll   name class  marks   age
# 4      5   asha    TE   63.28  NaN
# 10    10  anmol    BE   78.66  NaN

# %%
df.drop([3,6,9]) # drop rowsdf
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19
# 4     5    asha    TE  63.28   20
# 5     6  ayesha    BE  49.55   20
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20

# %%
df.drop('class',axis=1) # drop class col. axis=1 is used for coloumn to drop defalut is 0  used for rows
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %%
df['marks'].min(),df['marks'].max(),df['marks'].sum()
# Out:
# (49.55, 78.66, 644.9899999999999)

# %%
df['marks'].mean()
# Out:
# 64.499

# %%
df.max()
# Out:
# roll         10
# name     ayesha
# class        TE
# marks     78.66
# age          23
# dtype: object

# %%
df.max(numeric_only=True)
# Out:
# roll     10.00
# marks    78.66
# age      23.00
# dtype: float64

# %%
df.count()
# Out:
# roll     10
# name     10
# class    10
# marks    10
# age      10
# dtype: int64

# %%
df3.dtypes
# Out:
# roll        int64
# name       object
# class      object
# marks     float64
# age       float64
# dtype: object

# %%
df3['age']=df3['age'].fillna(20)
df['age'].astype(np.int64)
# Out:
# 0    22
# 1    21
# 2    19
# 3    20
# 4    20
# 5    20
# 6    19
# 7    23
# 8    20
# 9    21
# Name: age, dtype: int64

# %%
df3.dtypes
# Out:
# roll        int64
# name       object
# class      object
# marks     float64
# age       float64
# dtype: object

# %%
df['marks'].astype(np.int64)
# Out:
# 0    56
# 1    59
# 2    76
# 3    69
# 4    63
# 5    49
# 6    65
# 7    68
# 8    56
# 9    78
# Name: marks, dtype: int64

# %% [markdown]
# df3

# %%
df3
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28  20.0
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66  20.0
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    16 non-null     int64
#  1   name    16 non-null     object
#  2   class   15 non-null     object
#  3   marks   14 non-null     float64
#  4   age     16 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 772.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %% [markdown]
# ##### custom coloumn operation

# %%
df['marks']/10+0.45
# Out:
# 0    6.127
# 1    6.427
# 2    8.138
# 3    7.416
# 4    6.778
# 5    5.405
# 6    6.984
# 7    7.283
# 8    6.125
# 9    8.316
# Name: marks, dtype: float64

# %%
df['marks'] =df['marks']+0.5       #add 0.5 marks to all rows of mark coloumn

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  57.27   22
# 1     2     amit    TE  60.27   21
# 2     3   aniket    BE  77.38   19
# 3     4  ajinkya    TE  70.16   20
# 4     5     asha    TE  63.78   20
# 5     6   ayesha    BE  50.05   20
# 6     7     amar    BE  65.84   19
# 7     8    amita    BE  68.83   23
# 8     9     amol    TE  57.25   20
# 9    10    anmol    BE  79.16   21

# %%
df['cgpa'] =df['marks']/10+0.45
df
# Out:
#    roll     name class  marks  age   cgpa
# 0     1     anil    TE  57.27   22  6.177
# 1     2     amit    TE  60.27   21  6.477
# 2     3   aniket    BE  77.38   19  8.188
# 3     4  ajinkya    TE  70.16   20  7.466
# 4     5     asha    TE  63.78   20  6.828
# 5     6   ayesha    BE  50.05   20  5.455
# 6     7     amar    BE  65.84   19  7.034
# 7     8    amita    BE  68.83   23  7.333
# 8     9     amol    TE  57.25   20  6.175
# 9    10    anmol    BE  79.16   21  8.366

# %%
ndf= pd.DataFrame({
    'roll':range(1,11),
    'gender': ['M','M','M','F','M','M','M','F','M','M'],
    'cgpa': df['marks']  /10+.45 
})

# %%
ndf
# Out:
#    roll gender   cgpa
# 0     1      M  6.177
# 1     2      M  6.477
# 2     3      M  8.188
# 3     4      F  7.466
# 4     5      M  6.828
# 5     6      M  5.455
# 6     7      M  7.034
# 7     8      F  7.333
# 8     9      M  6.175
# 9    10      M  8.366

# %%
df
# Out:
#    roll     name class  marks  age   cgpa
# 0     1     anil    TE  57.27   22  6.177
# 1     2     amit    TE  60.27   21  6.477
# 2     3   aniket    BE  77.38   19  8.188
# 3     4  ajinkya    TE  70.16   20  7.466
# 4     5     asha    TE  63.78   20  6.828
# 5     6   ayesha    BE  50.05   20  5.455
# 6     7     amar    BE  65.84   19  7.034
# 7     8    amita    BE  68.83   23  7.333
# 8     9     amol    TE  57.25   20  6.175
# 9    10    anmol    BE  79.16   21  8.366

# %%
df = pd.read_csv("datasets/student.csv")
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
ndf.columns
# Out:
# Index(['roll', 'gender', 'cgpa'], dtype='object')

# %%
df.merge(ndf)
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  56.77   22      M  6.177
# 1     2     amit    TE  59.77   21      M  6.477
# 2     3   aniket    BE  76.88   19      M  8.188
# 3     4  ajinkya    TE  69.66   20      F  7.466
# 4     5     asha    TE  63.28   20      M  6.828
# 5     6   ayesha    BE  49.55   20      M  5.455
# 6     7     amar    BE  65.34   19      M  7.034
# 7     8    amita    BE  68.33   23      F  7.333
# 8     9     amol    TE  56.75   20      M  6.175
# 9    10    anmol    BE  78.66   21      M  8.366

# %%
help(df.merge)
# Out:
# Help on method merge in module pandas.core.frame:
#
# merge(right: 'DataFrame | Series', how: 'str' = 'inner', on: 'IndexLabel | None' = None, left_on: 'IndexLabel | None' = None, right_on: 'IndexLabel | None' = None, left_index: 'bool' = False, right_index: 'bool' = False, sort: 'bool' = False, suffixes: 'Suffixes' = ('_x', '_y'), copy: 'bool' = True, indicator: 'bool' = False, validate: 'str | None' = None) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Merge DataFrame or named Series objects with a database-style join.
#
#     A named Series object is treated as a DataFrame with a single named column.
#
#     The join is done on columns or indexes. If joining columns on
#     columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
#     on indexes or indexes on a column or columns, the index will be passed on.
#     When performing a cross merge, no column specifications to merge on are
#     allowed.
#
#     .. warning::
#
# ...

# %%
new_df =df.merge(ndf,on="roll")

# %%
new_df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  56.77   22      M  6.177
# 1     2     amit    TE  59.77   21      M  6.477
# 2     3   aniket    BE  76.88   19      M  8.188
# 3     4  ajinkya    TE  69.66   20      F  7.466
# 4     5     asha    TE  63.28   20      M  6.828
# 5     6   ayesha    BE  49.55   20      M  5.455
# 6     7     amar    BE  65.34   19      M  7.034
# 7     8    amita    BE  68.33   23      F  7.333
# 8     9     amol    TE  56.75   20      M  6.175
# 9    10    anmol    BE  78.66   21      M  8.366

# %%
df1 = pd.read_csv("datasets/student5.csv")
df1
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df,df1])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
tempdf = pd.concat([df,df1])
tempdf
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df,df1] ,ignore_index=True)
# Out:
#     roll     name class  marks  age
# 0      1     anil    TE  56.77   22
# 1      2     amit    TE  59.77   21
# 2      3   aniket    BE  76.88   19
# 3      4  ajinkya    TE  69.66   20
# 4      5     asha    TE  63.28   20
# 5      6   ayesha    BE  49.55   20
# 6      7     amar    BE  65.34   19
# 7      8    amita    BE  68.33   23
# 8      9     amol    TE  56.75   20
# 9     10    anmol    BE  78.66   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %% [markdown]
# ##### Boolean Filtering

# %%
df['marks']>60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
mask= df['marks']>60
df[mask]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
df[df['marks']>60]
# Out:
#    roll     name class  marks  age
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 9    10    anmol    BE  78.66   21

# %%
x = df[(df['marks']>60) & (df['class']=='BE') ] 
x
# Out:
#    roll    name class  marks  age
# 2     3  aniket    BE  76.88   19
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 9    10   anmol    BE  78.66   21

# %% [markdown]
# #### Export the data

# %%
x.to_csv("output.csv", index=False)

# %% [markdown]
# #### string function

# %%
name ="deepali"

# %%
name.upper()
# Out:
# 'DEEPALI'

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.replace('i','ee')
# Out:
# 0       aneel
# 1       ameet
# 2     aneeket
# 3    ajeenkya
# 4        asha
# 5      ayesha
# 6        amar
# 7      ameeta
# 8        amol
# 9       anmol
# Name: name, dtype: object

# %% [markdown]
# #### Grouping and aggregation

# %%
df['class'].value_counts()
# Out:
# TE    5
# BE    5
# Name: class, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 20    4
# 21    2
# 19    2
# 22    1
# 23    1
# Name: age, dtype: int64

# %%
gr =df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('TE')
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 8     9     amol    TE  56.75   20

# %%
gr.min()
# Out:
#        roll     name  marks  age
# class
# BE        3     amar  49.55   19
# TE        1  ajinkya  56.75   20
